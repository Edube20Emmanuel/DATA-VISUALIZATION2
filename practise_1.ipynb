# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("supermarket_sales - Sheet1.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
def exploratory_data_analysis(data):
    print("*"*52,"\n")
    print("\t********EXPLORATORY DATA ANALYSIS******")
    print("\tThe data has %d rows and %d columns"%(df.shape[0],df.shape[1]))
    print("\n\t***DATA TYPES OF OUR DATA SET***")
    for key,value in data.dtypes.items():
        print(f"\t{key}--------------->{value}")
    print("\n\t*****THE COLUMNS IN MY DATA SET*****")
    for column in data.columns:
        print(f"\t{column}")
exploratory_data_analysis(df)
# Out:
# ****************************************************
#
# 	********EXPLORATORY DATA ANALYSIS******
# 	The data has 1000 rows and 17 columns
#
# 	***DATA TYPES OF OUR DATA SET***
# 	Invoice ID--------------->object
# 	Branch--------------->object
# 	City--------------->object
# 	Customer type--------------->object
# 	Gender--------------->object
# 	Product line--------------->object
# 	Unit price--------------->float64
# 	Quantity--------------->int64
# 	Tax 5%--------------->float64
# 	Total--------------->float64
# 	Date--------------->object
# 	Time--------------->object
# 	Payment--------------->object
# 	cogs--------------->float64
# 	gross margin percentage--------------->float64
# 	gross income--------------->float64
# 	Rating--------------->float64
#
# 	*****THE COLUMNS IN MY DATA SET*****
# 	Invoice ID
# 	Branch
# 	City
# 	Customer type
# 	Gender
# 	Product line
# 	Unit price
# 	Quantity
# 	Tax 5%
# 	Total
# 	Date
# 	Time
# 	Payment
# 	cogs
# 	gross margin percentage
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
## Carring out some beautiful visualization
# Count plot
plt.figure(figsize=(20,10))
sns.countplot(data=df,x="Product line",hue="Gender",palette="dark6",)
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
## Plotting a bar plot
plt.figure(figsize=(20,10))
sns.barplot(data=df,x="Product line",y='Total',hue="Gender",hue_order=["Male","Female"],estimator=sum,palette="Set2",capsize=0.2)
plt.xticks(rotation = 45)
plt.grid(axis="y")

# %%
## Plottin box plots
sns.boxplot(data=df,x="City",y="Total",width=0.5,hue="Gender",linewidth=1,linecolor="green",showmeans=True,meanprops={"marker":"*",
                                                                                                                      "markerfacecolor":"white",
                                                                                                                      "markersize":12,
                                                                                                                      "markeredgecolor":"black"})
plt.xticks(rotation=36)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Yangon'), Text(1, 0, 'Naypyitaw'), Text(2, 0, 'Mandalay')])

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
sns.violinplot(data=df,x='Branch',y='Total',hue='Gender',split=True,cut=True)
# Out:
# <Axes: xlabel='Branch', ylabel='Total'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
plt.figure(figsize=(16,6))
sns.swarmplot(data=df,x='Product line',y='Total',hue='Gender',marker='*')
plt.grid()
