# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("supermarket_sales - Sheet1.csv")
df
# Out:
#      fInvoice ID Branch      City Customer type  Gender  \
# 0    303-96-2227      B  Mandalay        Normal  Female
# 1    690-01-6631      B  Mandalay        Normal    Male
# 2    602-16-6955      B  Mandalay        Normal  Female
# 3    430-53-4718      B  Mandalay        Member    Male
# 4    552-44-5977      B  Mandalay        Member    Male
# ..           ...    ...       ...           ...     ...
# 327  378-07-7001      B  Mandalay        Member    Male
# 328  730-61-8757      B  Mandalay        Member    Male
# 329  374-17-3652      B  Mandalay        Member  Female
# 330  868-81-1752      B  Mandalay        Normal    Male
# 331  692-27-8933      B  Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0        Home and lifestyle       97.38        10  48.6900  1022.4900
# 1       Fashion accessories       17.49        10   8.7450   183.6450
# 2         Sports and travel       76.60        10  38.3000   804.3000
# ...

# %%
plt.figure(figsize=(12,6))
plt.title("My Barplot Practise")
sns.barplot(x = "Product line",y = "Total",hue = "Gender",hue_order = ["Male","Female"],data = df,palette = "dark",capsize = 0.5,saturation = 5)
# Out:
# <Axes: title={'center': 'My Barplot Practise'}, xlabel='Product line', ylabel='Total'>

# %%
### Changing the estimator
plt.figure(figsize=(12,6))
plt.title("Sale by Product line in sum")
sns.barplot(x = "Product line",y = "Total",hue = "Gender",data=df,palette = "dark",errorbar=None,
            estimator = sum)
# Out:
# <Axes: title={'center': 'Sale by Product line in sum'}, xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(12,6))
plt.title("Sale by Product line")
sns.barplot(x = "Product line", y = "Total",hue = "Gender",capsize = 0.5,data = df,estimator = np.median,
            palette = "dark", saturation = 5)
# Out:
# <Axes: title={'center': 'Sale by Product line'}, xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(12,6))
plt.title("Sale by Product line")
sns.barplot(x = "Product line", y = "Total",data=df,facecolor=(0,0,0,0),
              linewidth = 3,
              edgecolor = sns.color_palette("dark"),errorbar = None,estimator = sum)
# Out:
# <Axes: title={'center': 'Sale by Product line'}, xlabel='Product line', ylabel='Total'>
